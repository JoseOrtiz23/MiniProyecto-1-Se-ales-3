# %% [markdown]
# # Miniproyecto 1 - Adquisición de datos y aplicación de técnicas de preprocesamiento para resolver un problema particular
# **Autores:**
# * Jackeline Morales Hernandez
#
# * Jose David Ortiz Miranda
#
# **Tratamiento de Señales III**
#
# **Facultad de Ingeniería**
#
# **Universidad de Antioquia**

# %%
## Librerias Importantes
import scipy.io as sc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from scipy import signal
from scipy.signal import find_peaks
from scipy.signal import butter, lfilter
from __future__ import division
from numpy import abs, sum, linspace
from numpy.fft import rfft
import pandas as pd

# %%
datosP1 = sc.loadmat('s14.mat')

# %%
signals = datosP1['data']
etiquetas = datosP1['labels']
# Esto me arrojará un nd array de n_video * id_signal * Ntimepoints

# %% [markdown]
# # 1. Extracción de características
#
# Para extraer las características, se deben recorrer los 40 videos o escenarios de prueba, procesarlos y almacenar el resultado de cada uno como un elemento de una matriz $\boldsymbol{X_{new}} \in {\mathbb{R}}^{N \times D}$ donde N es el número de observaciones (en este caso las realizaciones emocionales), y D es el número de características resultantes en el proceso de extracción.

# %% [markdown]
# ## 1.1 RESISTENCIA GALVANICA DE LA PIEL (GSR)
# ### De esta señal extreremos las siguientes caracteristicas:
# - Promedio de la resistencia de la piel.
# - Número de mínimos locales en la señal GSR.
# - Diez potencia espectral en las bandas [0 - 2.4] Hz.

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal GSR en todos los videos para el primero sujeto.

# %%
GSR = signals[:,36,:]
plt.plot(GSR)
plt.title('GSR')
plt.xlabel('Numero de videos')
plt.ylabel ('GSR medida en cada video')
plt.show()

# %% [markdown]
# ### 1.1.1 Promedio de la resistencia de la piel.

# %%
GSR_Total = []
for i in range(40):
    GSR = signals[i,36,:]
    GSR_promedio=np.mean(GSR)
    GSR_Total.append(GSR_promedio)

# %% [markdown]
# ### 1.1.2 Numero de minimos locales de la señal GSR.

# %%
for i in range(40):
    GSR = signals[i,36,:]
    GSR_num_min,_=find_peaks(-GSR)
    min_locales = len(GSR_num_min)
    GSR_Total.append(min_locales)

# %%
GSR_Total = np.array(GSR_Total).reshape(40, 2)

# %% [markdown]
# ### 1.1.3 Diez potencias espectrales en las bandas [0 - 2.4] Hz.

# %%
for i in range(40):
    # Definir los parámetros del filtro pasa banda (0.0-2.4 Hz)
    frec_corte_baja = 0.0001
    frec_corte_alta = 2.4
    nyq = 128
    frec_baja = frec_corte_baja / nyq
    frec_alta = frec_corte_alta / nyq
    # Diseñar el filtro pasa banda
    b, a = butter(N=4, Wn=[frec_baja, frec_alta], btype='band')
    # Aplicar el filtro pasa banda a la señal de GSR
    GSR_filtrada = lfilter(b, a, GSR[i]) # Inicializar la matriz filtrada
    # Calcular la FFT de la señal filtrada
    fft_resultado = np.fft.fft(GSR_filtrada)
    frecuencias = np.fft.fftfreq(len(fft_resultado), 1/128)
    # Calcula las potencias espectrales en la banda de 0 a 2.4 Hz
    potencias_banda = np.abs(fft_resultado)**2
    # Toma las 10 primeras potencias
    indices_top_10_potencias = np.argsort(potencias_banda)[::-1][:10]
    top_10_potencias = potencias_banda[indices_top_10_potencias]
    frecuencias_top_10 = frecuencias[indices_top_10_potencias]
    print(top_10_potencias)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 11
#       9 b, a = butter(N=4, Wn=[frec_baja, frec_alta], btype='band')
#      10 # Aplicar el filtro pasa banda a la señal de GSR
# ---> 11 GSR_filtrada = lfilter(b, a, GSR[i]) # Inicializar la matriz filtrada
#      12 # Calcular la FFT de la señal filtrada
#      13 fft_resultado = np.fft.fft(GSR_filtrada)
#
# File ~\anaconda3\lib\site-packages\scipy\signal\_signaltools.py:2126, in lfilter(b, a, x, axis, zi)
#    2124 else:
#    2125     if zi is None:
# -> 2126         return _sigtools._linear_filter(b, a, x, axis)
#    2127     else:
#    2128         return _sigtools._linear_filter(b, a, x, axis, zi)
#
# ValueError: selected axis is out of range

# %%
GSR = signals[0,36,:]
t = np.linspace(0,51,len(GSR))
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(t, GSR)
ax1.set_title('original signal')
#ax1.axis([0, 1, -2, 2])
sos = signal.butter(10, [0.05,0.15], 'bandpass', fs=128, output='sos')
filtered = signal.sosfilt(sos, GSR)
ax2.plot(t, filtered)
ax2.set_title('After 4 Hz low-pass filter')
#ax2.axis([0, 1, -2, 2])
ax2.set_xlabel('Time [seconds]')
plt.tight_layout()
plt.show()

# %%
GSR = signals[0,36,:]
indices_banda = np.where((frecuencias >= 0) & (frecuencias <= 2.4)
# Out:
#   Cell In[10], line 2
#     indices_banda = np.where((frecuencias >= 0) & (frecuencias <= 2.4)
#                                                                       ^
# SyntaxError: incomplete input

# %%
for i in range(40):
    GSR = signals[i,36,:]
    GSR_con_filtro = Filtrado_Bandas(GSR,0.00001,2.4)
    fft_resultado = np.fft.fft(GSR_con_filtro)
    frecuencias = np.fft.fftfreq(len(fft_resultado), d=128/len(fft_resultado))
    potencias_banda = np.abs(fft_resultado)**2
    indices_top_10_potencias = np.argsort(potencias_banda)[::-1][:10]
    top_10_potencias = potencias_banda[indices_top_10_potencias]
    frecuencias_top_10 = frecuencias[indices_top_10_potencias]
    print (top_10_potencias)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 for i in range(40):
#       2     GSR = signals[i,36,:]
# ----> 3     GSR_con_filtro = Filtrado_Bandas(GSR,0.00001,2.4)
#       4     fft_resultado = np.fft.fft(GSR_con_filtro)
#       5     frecuencias = np.fft.fftfreq(len(fft_resultado), d=128/len(fft_resultado))
#
# NameError: name 'Filtrado_Bandas' is not defined

# %% [markdown]
# ### 1.2 PLETISMOGRAFIA O VOLUMEN DE LA PRESION SANGUINEA
# ### De esta señal extreremos las siguientes caracteristicas:
# - Media y desviación estándar de la frecuencia cardiaca.
# - Espectro de potencia en las bandas de 0.2 a 0.3 Hz.
# - Componentes del espectro de potencia en las bandas de 0.15-0.5 Hz.

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal de pletismografia en todos los videos para el primero sujeto.

# %%
pleth = signals[:,38,:]
plt.plot(pleth)
plt.title('Pletismografia')
plt.xlabel('Numero de videos')
plt.ylabel ('Pletismografia medida en cada video')
plt.show()

# %% [markdown]
# ### 1.2.1 Media y desviación estándar de la frecuencia cardiaca.

# %%
for i in range(40):
    pleth = signals[i,38,:]
    pleth_media=np.mean(pleth)
for i in range(40):
    pleth = signals[i,38,:]
    pleth_std_des=np.std(pleth)

# %% [markdown]
# ### 1.2.2 Espectro de potencia en las bandas de 0.2 a 0.3 Hz.

# %% [markdown]
# ### 1.2.3 Componentes del espectro de potencia en las bandas de 0.15-0.5 Hz.

# %% [markdown]
# ## 1.3 PATRON DE RESPIRACIÓN
# ### De esta señal extreremos las siguientes caracteristicas:
# - Tasa respiratoria.
# - Media de la derivada (variación de la señal de respiración).
# - Ritmo respiratorio (centroide espectral).

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal del patrón de respiración en todos los videos para el primero sujeto.

# %%
respiration = signals[:,37,:]
plt.plot(respiration)
plt.title('Patrón de respiración')
plt.xlabel('Numero de videos')
plt.ylabel ('Respiración medida en cada video')
plt.show()

# %% [markdown]
# ### 1.3.1 Tasa respiratoria.

# %%
for i in range(40):
    respiration = signals[i,37,:]
    peaks, _ = signal.find_peaks(respiration, distance=128)  # Ajusta el umbral según tus datos
    t_respiration = np.diff(peaks)/128  # Calcula la duración entre picos
    respiration_rate = 60 / np.mean(t_respiration)

# %% [markdown]
# ### 1.3.2 Media de la derivada (variación de la señal de respiración).

# %%
for i in range(40):
    respiration = signals[i,39,:]
    respiration_derivada=np.gradient(respiration)
    respiration_derivada_promedio = np.mean(respiration_derivada)

# %% [markdown]
# ### 1.3.3 Ritmo respiratorio (centroide espectral).

# %%
for i in range(40):
    respiration = signals[i,39,:]
    espectro_respiration = abs(rfft(respiration))
    espectro_respiration_normalizado = espectro_respiration / sum(espectro_respiration)
    frecuencias_normalizadas = linspace(0, 1, len(espectro_respiration))
    espectro_central = sum(frecuencias_normalizadas * espectro_respiration_normalizado)

# %% [markdown]
# ## 1.4 TEMPERATURA DE LA PIEL
# ### De esta señal extreremos las siguientes caracteristicas:
# - Promedio de la señal de temperatura de la piel.
# - Promedio de la derivada.
# - Potencia espectral en las bandas ([0-0.1]Hz, [0.1-0.2]Hz)

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal de la temperatura de la piel en todos los videos para el primero sujeto.

# %%
temp = signals[:,39,:]
plt.plot(temp)
plt.title('Temperatura de la piel')
plt.xlabel('Numero de videos')
plt.ylabel ('Temperatura medida en cada video')
plt.show()

# %% [markdown]
# ## 1.4.1 Promedio de la señal de temperatura de la piel.

# %%
for i in range(40):
    temp = signals[i,39,:]
    temp_media=np.mean(temp)

# %% [markdown]
# ## 1.4.2 Promedio de la derivada.

# %%
for i in range(40):
    temp = signals[i,39,:]
    temp_derivada=np.gradient(temp)
    temp_derivada_promedio = np.mean(temp_derivada)

# %% [markdown]
# ## 1.4.3 Potencia espectral en las bandas ([0-0.1]Hz, [0.1-0.2]Hz).

# %% [markdown]
# ## 1.5 Electrooculograma (EOG)
#
# ### De esta señal extreremos las siguientes caracteristicas:
# - Tasa de parpadeo de los ojos.
# - Energía de la señal.
# - Media y varianza de la señal.

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal de EOG en dirección horizontal en todos los videos para el primero sujeto

# %%
hEOG = signals[:,32,:]
plt.plot(hEOG)
plt.title('hEOG')
plt.xlabel('Numero de videos')
plt.ylabel ('hEOG medida en cada video')
plt.show()

# %% [markdown]
# ## 1.5.1 Energia de la señal hEOG.

# %%
for i in range(40):
    hEOG = signals[i,32,:]
    energia = np.sum(np.abs(hEOG) ** 2)

# %% [markdown]
# ## 1.5.2 Media y varianza de la señal hEOG.

# %%
for i in range(40):
    hEOG = signals[i,32,:]
    hEOG_media=np.mean(hEOG)
for i in range(40):
    hEOG = signals[i,32,:]
    hEOG_var=np.var(hEOG)

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal de EOG en dirección vertical en todos los videos para el primero sujeto.

# %%
vEOG = signals[:,33,:]
plt.plot(vEOG)
plt.title('vEOG')
plt.xlabel('Numero de videos')
plt.ylabel ('vEOG medida en cada video')
plt.show()

# %% [markdown]
# ## 1.5.3 Tasa de parpadeo de los ojos en dirección vertical.

# %%
for i in range(40):
    vEOG = signals[i,33,:]
    fft_resultado_vEOG = np.fft.fft(vEOG)
    frecuencias = np.fft.fftfreq(len(vEOG))
    picos, _ = find_peaks(np.abs(fft_resultado_vEOG), distance=128) 
    tasa_de_parpadeo = len(picos) / (len(vEOG) / 128) * 60

# %% [markdown]
# ## 1.5.4 Energia de la señal vEOG.

# %%
for i in range(40):
    vEOG = signals[i,33,:]
    energia = np.sum(np.abs(vEOG ) ** 2)

# %% [markdown]
# ### 1.5.5 Media y varianza de la señal vEOG

# %%
for i in range(40):
    vEOG = signals[i,33,:]
    vEOG_media=np.mean(vEOG)
for i in range(40):
    vEOG = signals[i,33,:]
    vEOG_var=np.var(vEOG)

# %% [markdown]
# ### 1.6 Señales Electromiográficas (EMG)

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal del musculo cigomático mayor en todos los videos para el primero sujeto

# %%
zEMG = signals[:,34,:]
plt.plot(zEMG)
plt.title('zEMG')
plt.xlabel('Numero de videos')
plt.ylabel ('zEMG medida en cada video')
plt.show()

# %% [markdown]
# ## 1.6.1 Energia de la señal zEMG

# %%
for i in range(40):
    zEMG = signals[i,34,:]
    energia = np.sum(np.abs(zEMG) ** 2)

# %% [markdown]
# ## 1.6.2 Media y varianza de la señal zEMG

# %%
for i in range(40):
    zEMG = signals[i,34,:]
    zEMG_media=np.mean(zEMG)
for i in range(40):
    zEMG = signals[i,34,:]
    zEMG_var=np.var(zEMG)

# %% [markdown]
# ### Grafica que muestra el comportamiento de la señal del musculo trapecio en todos los videos para el primero sujeto

# %%
tEMG = signals[:,35,:]
plt.plot(tEMG)
plt.title('tEMG')
plt.xlabel('Numero de videos')
plt.ylabel ('tEMG medida en cada video')
plt.show()

# %% [markdown]
# ## 1.6.3 Energia de la señal tEMG

# %%
for i in range(40):
    tEMG = signals[i,35,:]
    energia = np.sum(np.abs(tEMG) ** 2)

# %% [markdown]
# ## 1.6.4 Media y varianza de la señal tEMG

# %%
for i in range(40):
    tEMG = signals[i,35,:]
    tEMG_media=np.mean(tEMG)
for i in range(40):
    tEMG = signals[i,35,:]
    tEMG_var=np.var(tEMG)

# %% [markdown]
# ### 1.7 Electroencefalograma (EMG)

# %% [markdown]
# ## Creación del DataFream

# %%
def caracterizadorDEAP(xGSR): #funcion donde caracteriza y concardena los vectores
    # Asegura que todos los elementos de nuevo_vector sean arrays 1D
    xGSR = [np.array(elem).ravel() if isinstance(elem, np.ndarray) else elem for elem in xGSR]
   
    # Convierte nuevo_vector a un array de NumPy y aplica reshape para asegurar que sea compatible
    xGSR = np.array(xGSR).reshape(40, -1)

    # Concatena todos los datos en un solo array
    xTrial = np.hstack((xGSR))
    return xTrial

# %%
# Llama a la función caracterizadorDEAP con nuevo_vector
xTrial = caracterizadorDEAP(GSR_Total)
xTrial
# Out:
# array([-1.80056834e+04, -8.79465075e+03, -1.33140863e+03,  3.49128382e+03,
#        -3.73638602e+03, -8.48909184e+02, -8.99958368e+03, -5.17923350e+02,
#        -9.16506966e+03,  5.51986595e+03,  2.56039553e+03, -1.81838127e+03,
#         9.66701339e+03, -1.17654556e+04, -6.25622806e+02, -2.64203705e+03,
#        -4.01437602e+03, -3.40314583e+03,  5.40660118e+03,  4.14820507e+03,
#         3.76462098e+03,  6.53160069e+03,  5.65766677e+02,  3.77464893e+03,
#         2.71240223e+03, -3.37256313e+03,  7.40832420e+03,  9.50612202e+03,
#         3.64753490e+03, -2.02659834e+04,  6.08223192e+03,  5.11458325e+03,
#        -6.35855523e+03, -3.93944638e+03,  5.19965529e+03,  6.22243770e+03,
#         2.97308427e+03,  4.89712258e+03, -4.76027825e+03, -8.05348746e+03,
#         7.80000000e+01,  6.40000000e+01,  4.80000000e+01,  8.50000000e+01,
#         9.10000000e+01,  7.40000000e+01,  6.40000000e+01,  8.00000000e+01,
#         4.10000000e+01,  1.11000000e+02,  1.30000000e+02,  1.00000000e+02,
#         6.30000000e+01,  6.80000000e+01,  7.00000000e+01,  6.00000000e+01,
#         3.30000000e+01,  8.70000000e+01,  6.10000000e+01,  7.00000000e+01,
#         1.76000000e+02,  2.00000000e+01,  3.50000000e+01,  6.20000000e+01,
#         6.50000000e+01,  9.00000000e+01,  8.70000000e+01,  3.60000000e+01,
#         1.05000000e+02,  5.90000000e+01,  6.20000000e+01,  8.40000000e+01,
#         6.00000000e+01,  6.40000000e+01,  8.60000000e+01,  4.80000000e+01,
#         2.80000000e+01,  6.70000000e+01,  4.00000000e+01,  5.80000000e+01])

# %%
# Llama a la función caracterizadorDEAP con nuevo_vector
xTrial = caracterizadorDEAP(GSR_Total)

#Se crea el dataFrame
dataFrame_P1 = pd.DataFrame(GSR_Total)
# Cambiar nombres de las columnas usando rename
nuevos_nombres = ['GSR1']
dataFrame_P1.columns = nuevos_nombres
dataFrame_P1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 8
#       6 # Cambiar nombres de las columnas usando rename
#       7 nuevos_nombres = ['GSR1']
# ----> 8 dataFrame_P1.columns = nuevos_nombres
#       9 dataFrame_P1
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:230, in BaseBlockManager.set_axis(self, axis, new_labels)
#     228 def set_axis(self, axis: int, new_labels: Index) -> None:
#     229     # Caller is responsible for ensuring we have an Index object.
# --> 230     self._validate_set_axis(axis, new_labels)
#     231     self.axes[axis] = new_labels
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 2 elements, new values have 1 elements
